# %%
import pandas as pd

# %%
df = pd.read_csv('climate_change_jan_2025.csv')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df.head(1)['post_text']
# Out:
# 0    Greed is the motivator.They don’t want poors t...
# Name: post_text, dtype: object
