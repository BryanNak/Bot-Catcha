# %%
# !pip install -U transformers datasets evaluate accelerate timm
# Out:
# Requirement already satisfied: transformers in c:\users\jarre\anaconda3\lib\site-packages (5.5.0)
# Requirement already satisfied: datasets in c:\users\jarre\appdata\roaming\python\python313\site-packages (3.6.0)
# Collecting datasets
#   Downloading datasets-4.8.4-py3-none-any.whl.metadata (19 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting accelerate
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Collecting timm
#   Downloading timm-1.0.26-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\jarre\anaconda3\lib\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\jarre\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\jarre\appdata\roaming\python\python313\site-packages (from transformers) (0.20.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\jarre\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\jarre\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\jarre\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.11.0)
# Requirement already satisfied: certifi in c:\users\jarre\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\jarre\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\jarre\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\jarre\appdata\roaming\python\python313\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: xxhash in c:\users\jarre\appdata\roaming\python\python313\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: psutil in c:\users\jarre\appdata\roaming\python\python313\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: torch>=2.0.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from accelerate) (2.9.0+cu128)
# Requirement already satisfied: torchvision in c:\users\jarre\appdata\roaming\python\python313\site-packages (from timm) (0.24.0+cu128)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch>=2.0.0->accelerate) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\users\jarre\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torchvision->timm) (11.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from typer->transformers) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from typer->transformers) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers) (0.1.2)
# Downloading datasets-4.8.4-py3-none-any.whl (526 kB)
#    ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/527.0 kB ? eta -:--:--
#    ---------------------------------------- 527.0/527.0 kB 2.0 MB/s  0:00:00
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
# Downloading timm-1.0.26-py3-none-any.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 3.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 4.6 MB/s  0:00:00
# Installing collected packages: timm, datasets, accelerate, evaluate
#
#    ---------------------------------------- 0/4 [timm]
#    ---------------------------------------- 0/4 [timm]
#    ---------------------------------------- 0/4 [timm]
#    ---------------------------------------- 0/4 [timm]
#    ---------------------------------------- 0/4 [timm]
#    ---------------------------------------- 0/4 [timm]
#    ---------------------------------------- 0/4 [timm]
#    ---------------------------------------- 0/4 [timm]
#   Attempting uninstall: datasets
#    ---------------------------------------- 0/4 [timm]
#     Found existing installation: datasets 3.6.0
#    ---------------------------------------- 0/4 [timm]
#     Uninstalling datasets-3.6.0:
#    ---------------------------------------- 0/4 [timm]
#       Successfully uninstalled datasets-3.6.0
#    ---------------------------------------- 0/4 [timm]
#    ---------- ----------------------------- 1/4 [datasets]
#    ---------- ----------------------------- 1/4 [datasets]
#    ---------- ----------------------------- 1/4 [datasets]
#    ---------- ----------------------------- 1/4 [datasets]
#    -------------------- ------------------- 2/4 [accelerate]
#    -------------------- ------------------- 2/4 [accelerate]
#    -------------------- ------------------- 2/4 [accelerate]
#    ---------------------------------------- 4/4 [evaluate]
#
# Successfully installed accelerate-1.13.0 datasets-4.8.4 evaluate-0.4.6 timm-1.0.26
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\jarre\appdata\roaming\python\python313\site-packages (2.9.0+cu128)
# Requirement already satisfied: filelock in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\jarre\appdata\roaming\python\python313\site-packages (from torch) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jarre\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -c "from transformers import pipeline; print(pipeline('sentiment-analysis')('hugging face is the best'))"
# Out:
# [{'label': 'POSITIVE', 'score': 0.999839186668396}]
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
#
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# Loading weights: 100%|##########| 104/104 [00:00<00:00, 8812.99it/s]

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-hf", dtype="auto", device_map="auto")
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf")
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\huggingface_hub\utils\_http.py:761, in hf_raise_for_status(response, endpoint_name)
#     760 try:
# --> 761     response.raise_for_status()
#     762 except httpx.HTTPStatusError as e:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\utils\hub.py:422, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     420 if len(full_filenames) == 1:
#     421     # This is slightly better for only 1 file
# --> 422     hf_hub_download(
#     423         path_or_repo_id,
#     424         filenames[0],
#     425         subfolder=None if len(subfolder) == 0 else subfolder,
#     426         repo_type=repo_type,
#     427         revision=revision,
#     428         cache_dir=cache_dir,
#     429         user_agent=user_agent,
#     430         force_download=force_download,
#     431         proxies=proxies,
#     432         token=token,
#     433         local_files_only=local_files_only,
#     434         tqdm_class=tqdm_class,
#     435     )
#     436 else:
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:986, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     985 else:
# --> 986     return _hf_hub_download_to_cache_dir(
#     987         # Destination
#     988         cache_dir=cache_dir,
#     989         # File info
#     990         repo_id=repo_id,
#     991         filename=filename,
#     992         repo_type=repo_type,
#     993         revision=revision,
#     994         # HTTP info
#     995         endpoint=endpoint,
#     996         etag_timeout=etag_timeout,
#     997         headers=hf_headers,
#     998         token=token,
#     999         # Additional options
#    1000         local_files_only=local_files_only,
#    1001         force_download=force_download,
#    1002         tqdm_class=tqdm_class,
#    1003         dry_run=dry_run,
#    1004     )
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1137, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1136     if head_call_error is not None:
# -> 1137         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1139 # From now on, etag, commit_hash, url and size are not None.
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1766, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1761 elif isinstance(head_call_error, (RepositoryNotFoundError, GatedRepoError)) or (
#    1762     isinstance(head_call_error, HfHubHTTPError) and head_call_error.response.status_code == 401
#    1763 ):
#    1764     # Repo not found or gated => let's raise the actual error
#    1765     # Unauthorized => likely a token issue => let's raise the actual error
# -> 1766     raise head_call_error
#    1767 else:
#    1768     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1653, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors)
#    1652 try:
# -> 1653     metadata = get_hf_file_metadata(
#    1654         url=url,
#    1655         timeout=etag_timeout,
#    1656         headers=headers,
#    1657         token=token,
#    1658         endpoint=endpoint,
#    1659         retry_on_errors=retry_on_errors,
#    1660     )
#    1661 except RemoteEntryNotFoundError as http_error:
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1576, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1575 # Retrieve metadata
# -> 1576 response = _httpx_follow_relative_redirects_with_backoff(
#    1577     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1578 )
#    1579 hf_raise_for_status(response)
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\utils\_http.py:692, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     685 response = http_backoff(
#     686     method=method,
#     687     url=url,
#    (...)    690     **no_retry_kwargs,
#     691 )
# --> 692 hf_raise_for_status(response)
#     694 # Check if response is a relative redirect
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\utils\_http.py:796, in hf_raise_for_status(response, endpoint_name)
#     795     gated_err.repo_id = repo_id
# --> 796     raise gated_err from e
#     798 elif error_message == "Access to this resource is disabled.":
#
# GatedRepoError: 403 Client Error. (Request ID: Root=1-69cf1b02-7517ef870d1b4c503119f87f;3755e76d-53d6-467e-bd9b-853113ea815e)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-hf is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-2-7b-hf to ask for access.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 3
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 3 model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-hf", dtype="auto", device_map="auto")
#       4 tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf")
#
# File ~\anaconda3\Lib\site-packages\transformers\models\auto\auto_factory.py:329, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     326 if kwargs.get("quantization_config") is not None:
#     327     _ = kwargs.pop("quantization_config")
# --> 329 config, kwargs = AutoConfig.from_pretrained(
#     330     pretrained_model_name_or_path,
#     331     return_unused_kwargs=True,
#     332     code_revision=code_revision,
#     333     _commit_hash=commit_hash,
#     334     **hub_kwargs,
#     335     **kwargs,
#     336 )
#     338 # if torch_dtype=auto was passed here, ensure to pass it on
#     339 if kwargs_orig.get("torch_dtype", None) == "auto":
#
# File ~\anaconda3\Lib\site-packages\transformers\models\auto\configuration_auto.py:1483, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1480 trust_remote_code = kwargs.pop("trust_remote_code", None)
#    1481 code_revision = kwargs.pop("code_revision", None)
# -> 1483 config_dict, unused_kwargs = PreTrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1484 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#    1485 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File ~\anaconda3\Lib\site-packages\transformers\configuration_utils.py:667, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     665 original_kwargs = copy.deepcopy(kwargs)
#     666 # Get config dict associated with the base config file
# --> 667 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     668 if config_dict is None:
#     669     return {}, kwargs
#
# File ~\anaconda3\Lib\site-packages\transformers\configuration_utils.py:722, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     718 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     720 try:
#     721     # Load from local folder or from cache or download from model Hub and cache
# --> 722     resolved_config_file = cached_file(
#     723         pretrained_model_name_or_path,
#     724         configuration_file,
#     725         cache_dir=cache_dir,
#     726         force_download=force_download,
#     727         proxies=proxies,
#     728         local_files_only=local_files_only,
#     729         token=token,
#     730         user_agent=user_agent,
#     731         revision=revision,
#     732         subfolder=subfolder,
#     733         _commit_hash=commit_hash,
#     734     )
#     735     if resolved_config_file is None:
#     736         return None, kwargs
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\hub.py:278, in cached_file(path_or_repo_id, filename, **kwargs)
#     223 def cached_file(
#     224     path_or_repo_id: str | os.PathLike,
#     225     filename: str,
#     226     **kwargs,
#     227 ) -> str | None:
#     228     """
#     229     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     230
#    (...)    276     ```
#     277     """
# --> 278     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     279     file = file[0] if file is not None else file
#     280     return file
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\hub.py:488, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     486     if not _raise_exceptions_for_gated_repo:
#     487         return None
# --> 488     raise OSError(
#     489         "You are trying to access a gated repo.\nMake sure to have access to it at "
#     490         f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#     491     ) from e
#     492 elif isinstance(e, LocalEntryNotFoundError):
#     493     if not _raise_exceptions_for_connection_errors:
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-2-7b-hf.
# 403 Client Error. (Request ID: Root=1-69cf1b02-7517ef870d1b4c503119f87f;3755e76d-53d6-467e-bd9b-853113ea815e)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-hf is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-2-7b-hf to ask for access.
